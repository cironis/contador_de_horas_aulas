# %%
import pandas as pd
from auxiliar.google_sheets import *
from dotenv import load_dotenv
load_dotenv()
import os

base = get_sheet_data("base_alunos")
base
# Out:
#        aluno hora_aula
# 0   Bernardo       260
# 1     Helena       150
# 2      Lucas       100
# 3       Theo       200
# 4  Cristiano       180
# 5      Guido       150
# 6    Mariana       130
# 7     Milena       130
